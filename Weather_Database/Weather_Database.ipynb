# %%
# Dependencies and Setup
import requests
import gmaps
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e2b2598156326fbbcb8f72d2a6b6e593

# %%
# create a set of random latitude and longitude combination.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 734

# %%
# Create an empty list to hold the weather data.
#from datetime import datetime
#city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+") 
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
        

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 15 | albany
# Processing Record 2 of Set 15 | rawson
# Processing Record 3 of Set 15 | mataura
# Processing Record 4 of Set 15 | guerrero negro
# Processing Record 5 of Set 15 | ipixuna
# Processing Record 6 of Set 15 | blacksburg
# Processing Record 7 of Set 15 | busselton
# Processing Record 8 of Set 15 | pisco
# Processing Record 9 of Set 15 | hobart
# Processing Record 10 of Set 15 | mar del plata
# Processing Record 11 of Set 15 | taoudenni
# Processing Record 12 of Set 15 | pevek
# Processing Record 13 of Set 15 | bathsheba
# Processing Record 14 of Set 15 | vestmanna
# Processing Record 15 of Set 15 | port pirie
# Processing Record 16 of Set 15 | lasa
# Processing Record 17 of Set 15 | ushuaia
# Processing Record 18 of Set 15 | punta arenas
# Processing Record 19 of Set 15 | saint george
# Processing Record 20 of Set 15 | villanueva
# Processing Record 21 of Set 15 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 15 | castro
# Processing Record 23 of Set 15 | rikitea
# Processing Record 24 of Set 15 | new norfolk
# Processing Record 25 of Set 15 | sarankhola
# Processing Record 26 of Set 15 | murom
# Processing Record 27 of Set 15 | vila franca do campo
# Processing Record 28 of Set 15 | vuktyl
# Processing Record 29 of Set 15 | maxixe
# Processing Record 30 of Set 15 | san felipe
# Processing Record 31 of Set 15 | grandview
# Processing Record 32 of Set 15 | tshane
# Processing Record 33 of Set 15 | hermanus
# Processing Record 34 of Set 15 | cape town
# Processing Record 35 of Set 15 | vaini
# Processing Record 36 of Set 15 | kavaratti
# Processing Record 37 of Set 15 | necochea
# Processing Record 38 of Set 15 | baraya
# Processing Record 39 of Set 15 | zachagansk
# City not found. Skipping...
# Processing Record 40 of Set 15 | saint-philippe
# Processing Record 41 of Set 15 | hithadhoo
# Processing Record 42 of Set 15 | hilo
# Processing Record 43 of Set 15 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 15 | georgetown
# Processing Record 45 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 46 of Set 15 | tabou
# Processing Record 47 of Set 15 | sangmelima
# Processing Record 48 of Set 15 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 15 | atuona
# Processing Record 50 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 16 | dudinka
# Processing Record 2 of Set 16 | barrow
# Processing Record 3 of Set 16 | lebu
# Processing Record 4 of Set 16 | zhongshu
# Processing Record 5 of Set 16 | avarua
# Processing Record 6 of Set 16 | leh
# Processing Record 7 of Set 16 | bredasdorp
# Processing Record 8 of Set 16 | constitucion
# Processing Record 9 of Set 16 | bambous virieux
# Processing Record 10 of Set 16 | talnakh
# Processing Record 11 of Set 16 | gorontalo
# Processing Record 12 of Set 16 | nikolskoye
# Processing Record 13 of Set 16 | awbari
# Processing Record 14 of Set 16 | vila
# Processing Record 15 of Set 16 | quelimane
# Processing Record 16 of Set 16 | progress
# Processing Record 17 of Set 16 | alice springs
# Processing Record 18 of Set 16 | ilulissat
# Processing Record 19 of Set 16 | urumqi
# Processing Record 20 of Set 16 | puerto ayora
# Processing Record 21 of Set 16 | dzhebariki-khaya
# Processing Record 22 of Set 16 | kapaa
# Processing Record 23 of Set 16 | souillac
# Processing Record 24 of Set 16 | huarmey
# Processing Record 25 of Set 16 | qaanaaq
# Processing Record 26 of Set 16 | bubaque
# Processing Record 27 of Set 16 | aljezur
# Processing Record 28 of Set 16 | chokurdakh
# Processing Record 29 of Set 16 | gizo
# Processing Record 30 of Set 16 | jamestown
# Processing Record 31 of Set 16 | ustka
# Processing Record 32 of Set 16 | east london
# Processing Record 33 of Set 16 | falealupo
# City not found. Skipping...
# Processing Record 34 of Set 16 | thinadhoo
# Processing Record 35 of Set 16 | hihifo
# City not found. Skipping...
# Processing Record 36 of Set 16 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 16 | port elizabeth
# Processing Record 38 of Set 16 | namibe
# Processing Record 39 of Set 16 | batasan
# Processing Record 40 of Set 16 | tagusao
# Processing Record 41 of Set 16 | cabra
# Processing Record 42 of Set 16 | yellowknife
# Processing Record 43 of Set 16 | tuatapere
# Processing Record 44 of Set 16 | siavonga
# Processing Record 45 of Set 16 | cabo san lucas
# Processing Record 46 of Set 16 | sjenica
# Processing Record 47 of Set 16 | codrington
# Processing Record 48 of Set 16 | zenica
# Processing Record 49 of Set 16 | kieta
# Processing Record 50 of Set 16 | thompson
# Processing Record 1 of Set 17 | chapais
# Processing Record 2 of Set 17 | enterprise
# Processing Record 3 of Set 17 | almaznyy
# Processing Record 4 of Set 17 | praia da vitoria
# Processing Record 5 of Set 17 | plettenberg bay
# Processing Record 6 of Set 17 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 17 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 17 | yanchukan
# City not found. Skipping...
# Processing Record 9 of Set 17 | viedma
# Processing Record 10 of Set 17 | tidore
# City not found. Skipping...
# Processing Record 11 of Set 17 | severo-kurilsk
# Processing Record 12 of Set 17 | saint-augustin
# Processing Record 13 of Set 17 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 17 | faanui
# Processing Record 15 of Set 17 | samfya
# Processing Record 16 of Set 17 | kodiak
# Processing Record 17 of Set 17 | nyagan
# Processing Record 18 of Set 17 | sitka
# Processing Record 19 of Set 17 | flinders
# Processing Record 20 of Set 17 | kinango
# Processing Record 21 of Set 17 | moose factory
# Processing Record 22 of Set 17 | wajir
# Processing Record 23 of Set 17 | takhtamygda
# Processing Record 24 of Set 17 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 17 | coihaique
# Processing Record 26 of Set 17 | dikson
# Processing Record 27 of Set 17 | butaritari
# Processing Record 28 of Set 17 | beaucaire
# Processing Record 29 of Set 17 | marabba
# Processing Record 30 of Set 17 | maloy
# Processing Record 31 of Set 17 | port alfred
# Processing Record 32 of Set 17 | bengkulu
# Processing Record 33 of Set 17 | parati
# Processing Record 34 of Set 17 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 17 | ondjiva
# Processing Record 36 of Set 17 | kahului
# Processing Record 37 of Set 17 | yumen
# Processing Record 38 of Set 17 | bonthe
# Processing Record 39 of Set 17 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 17 | bethel
# Processing Record 41 of Set 17 | sharlyk
# Processing Record 42 of Set 17 | arraial do cabo
# Processing Record 43 of Set 17 | port hedland
# Processing Record 44 of Set 17 | okha
# Processing Record 45 of Set 17 | bluff
# Processing Record 46 of Set 17 | rocha
# Processing Record 47 of Set 17 | birao
# Processing Record 48 of Set 17 | cidreira
# Processing Record 49 of Set 17 | kurilsk
# Processing Record 50 of Set 17 | onega
# Processing Record 1 of Set 18 | karratha
# Processing Record 2 of Set 18 | baicheng
# Processing Record 3 of Set 18 | namie
# Processing Record 4 of Set 18 | kushiro
# Processing Record 5 of Set 18 | buala
# Processing Record 6 of Set 18 | deshnok
# Processing Record 7 of Set 18 | rungata
# City not found. Skipping...
# Processing Record 8 of Set 18 | husavik
# Processing Record 9 of Set 18 | ponta do sol
# Processing Record 10 of Set 18 | tautira
# Processing Record 11 of Set 18 | bandarbeyla
# Processing Record 12 of Set 18 | gannan
# Processing Record 13 of Set 18 | monte patria
# Processing Record 14 of Set 18 | izhma
# Processing Record 15 of Set 18 | clyde river
# Processing Record 16 of Set 18 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 18 | kargil
# Processing Record 18 of Set 18 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 18 | ribeira grande
# Processing Record 20 of Set 18 | saryshagan
# City not found. Skipping...
# Processing Record 21 of Set 18 | isangel
# Processing Record 22 of Set 18 | balkhash
# Processing Record 23 of Set 18 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 18 | skjervoy
# Processing Record 25 of Set 18 | blagoyevo
# Processing Record 26 of Set 18 | tuktoyaktuk
# Processing Record 27 of Set 18 | pontes e lacerda
# Processing Record 28 of Set 18 | tonantins
# Processing Record 29 of Set 18 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 18 | cockburn town
# Processing Record 31 of Set 18 | qeshm
# Processing Record 32 of Set 18 | kangaatsiaq
# Processing Record 33 of Set 18 | victoria
# Processing Record 34 of Set 18 | seoul
# Processing Record 35 of Set 18 | bontang
# Processing Record 36 of Set 18 | penzance
# Processing Record 37 of Set 18 | sao filipe
# Processing Record 38 of Set 18 | vila velha
# Processing Record 39 of Set 18 | rosetta
# Processing Record 40 of Set 18 | navotas
# Processing Record 41 of Set 18 | kloulklubed
# Processing Record 42 of Set 18 | nantucket
# Processing Record 43 of Set 18 | yeniseysk
# Processing Record 44 of Set 18 | kathmandu
# Processing Record 45 of Set 18 | harper
# Processing Record 46 of Set 18 | opobo
# City not found. Skipping...
# Processing Record 47 of Set 18 | andujar
# Processing Record 48 of Set 18 | dingle
# Processing Record 49 of Set 18 | matanzas
# Processing Record 50 of Set 18 | iqaluit
# Processing Record 1 of Set 19 | oksfjord
# Processing Record 2 of Set 19 | kaitangata
# Processing Record 3 of Set 19 | shimoda
# Processing Record 4 of Set 19 | narsaq
# Processing Record 5 of Set 19 | manicore
# Processing Record 6 of Set 19 | atbasar
# Processing Record 7 of Set 19 | luanda
# Processing Record 8 of Set 19 | el carrizo
# Processing Record 9 of Set 19 | la asuncion
# Processing Record 10 of Set 19 | kirakira
# Processing Record 11 of Set 19 | tasiilaq
# Processing Record 12 of Set 19 | coquimbo
# Processing Record 13 of Set 19 | erzin
# Processing Record 14 of Set 19 | turukhansk
# Processing Record 15 of Set 19 | port hardy
# Processing Record 16 of Set 19 | bethalto
# Processing Record 17 of Set 19 | kondinskoye
# Processing Record 18 of Set 19 | niteroi
# Processing Record 19 of Set 19 | cap malheureux
# Processing Record 20 of Set 19 | kralendijk
# Processing Record 21 of Set 19 | nizhneangarsk
# Processing Record 22 of Set 19 | labrea
# Processing Record 23 of Set 19 | magistralnyy
# Processing Record 24 of Set 19 | padang
# Processing Record 25 of Set 19 | tiksi
# Processing Record 26 of Set 19 | den helder
# Processing Record 27 of Set 19 | maragogi
# Processing Record 28 of Set 19 | urdzhar
# City not found. Skipping...
# Processing Record 29 of Set 19 | dangriga
# Processing Record 30 of Set 19 | north bend
# Processing Record 31 of Set 19 | marathon
# Processing Record 32 of Set 19 | cavalcante
# Processing Record 33 of Set 19 | cherskiy
# Processing Record 34 of Set 19 | mahebourg
# Processing Record 35 of Set 19 | tabas
# Processing Record 36 of Set 19 | kiunga
# Processing Record 37 of Set 19 | verkhnevilyuysk
# Processing Record 38 of Set 19 | marystown
# Processing Record 39 of Set 19 | high rock
# Processing Record 40 of Set 19 | sorrento
# Processing Record 41 of Set 19 | prudnik
# Processing Record 42 of Set 19 | takoradi
# Processing Record 43 of Set 19 | poum
# Processing Record 44 of Set 19 | sao joao da barra
# Processing Record 45 of Set 19 | tabiauea
# City not found. Skipping...
# Processing Record 46 of Set 19 | uwayl
# City not found. Skipping...
# Processing Record 47 of Set 19 | buchanan
# Processing Record 48 of Set 19 | omsukchan
# Processing Record 49 of Set 19 | ancud
# Processing Record 50 of Set 19 | tripoli
# Processing Record 1 of Set 20 | shingu
# Processing Record 2 of Set 20 | samarai
# Processing Record 3 of Set 20 | teguldet
# Processing Record 4 of Set 20 | lavrentiya
# Processing Record 5 of Set 20 | lagoa
# Processing Record 6 of Set 20 | vila do maio
# Processing Record 7 of Set 20 | avera
# Processing Record 8 of Set 20 | caravelas
# Processing Record 9 of Set 20 | san cristobal
# Processing Record 10 of Set 20 | gazanjyk
# Processing Record 11 of Set 20 | vilhena
# Processing Record 12 of Set 20 | hailar
# Processing Record 13 of Set 20 | havelock
# Processing Record 14 of Set 20 | alofi
# Processing Record 15 of Set 20 | camana
# Processing Record 16 of Set 20 | osvaldo cruz
# Processing Record 17 of Set 20 | santa ines
# Processing Record 18 of Set 20 | madang
# Processing Record 19 of Set 20 | hirara
# Processing Record 20 of Set 20 | saskylakh
# Processing Record 21 of Set 20 | natal
# Processing Record 22 of Set 20 | torbay
# Processing Record 23 of Set 20 | gamba
# Processing Record 24 of Set 20 | portland
# Processing Record 25 of Set 20 | kijang
# Processing Record 26 of Set 20 | bahir dar
# Processing Record 27 of Set 20 | lazaro cardenas
# Processing Record 28 of Set 20 | qui nhon
# Processing Record 29 of Set 20 | paamiut
# Processing Record 30 of Set 20 | goure
# Processing Record 31 of Set 20 | wagar
# Processing Record 32 of Set 20 | victor harbor
# Processing Record 33 of Set 20 | kavieng
# Processing Record 34 of Set 20 | kaeo
# Processing Record 35 of Set 20 | yulara
# Processing Record 36 of Set 20 | bermeo
# Processing Record 37 of Set 20 | moratuwa
# Processing Record 38 of Set 20 | khartoum
# Processing Record 39 of Set 20 | clive
# Processing Record 40 of Set 20 | santa lucia
# Processing Record 41 of Set 20 | leningradskiy
# Processing Record 42 of Set 20 | eureka
# Processing Record 43 of Set 20 | longyearbyen
# Processing Record 44 of Set 20 | huejuquilla el alto
# Processing Record 45 of Set 20 | klaksvik
# Processing Record 46 of Set 20 | bamiantong
# Processing Record 47 of Set 20 | luang prabang
# Processing Record 48 of Set 20 | namatanai
# Processing Record 49 of Set 20 | margate
# Processing Record 50 of Set 20 | taree
# Processing Record 1 of Set 21 | arlit
# Processing Record 2 of Set 21 | bjala
# City not found. Skipping...
# Processing Record 3 of Set 21 | teneguiban
# City not found. Skipping...
# Processing Record 4 of Set 21 | ukmerge
# Processing Record 5 of Set 21 | luderitz
# Processing Record 6 of Set 21 | nyandoma
# Processing Record 7 of Set 21 | pacific grove
# Processing Record 8 of Set 21 | boa vista
# Processing Record 9 of Set 21 | umm durman
# City not found. Skipping...
# Processing Record 10 of Set 21 | khandyga
# Processing Record 11 of Set 21 | kedrovyy
# Processing Record 12 of Set 21 | bahia blanca
# Processing Record 13 of Set 21 | airai
# Processing Record 14 of Set 21 | ascension
# Processing Record 15 of Set 21 | carnarvon
# Processing Record 16 of Set 21 | abadan
# Processing Record 17 of Set 21 | ruatoria
# City not found. Skipping...
# Processing Record 18 of Set 21 | roma
# Processing Record 19 of Set 21 | coria
# Processing Record 20 of Set 21 | soure
# Processing Record 21 of Set 21 | starogard gdanski
# Processing Record 22 of Set 21 | biak
# Processing Record 23 of Set 21 | komsomolskiy
# Processing Record 24 of Set 21 | churapcha
# Processing Record 25 of Set 21 | nadym
# Processing Record 26 of Set 21 | dongying
# Processing Record 27 of Set 21 | guane
# Processing Record 28 of Set 21 | eidfjord
# Processing Record 29 of Set 21 | quatre cocos
# Processing Record 30 of Set 21 | fortuna
# Processing Record 31 of Set 21 | mantua
# Processing Record 32 of Set 21 | hovd
# Processing Record 33 of Set 21 | borodino
# Processing Record 34 of Set 21 | mangan
# Processing Record 35 of Set 21 | chuy
# Processing Record 36 of Set 21 | haines junction
# Processing Record 37 of Set 21 | port hawkesbury
# Processing Record 38 of Set 21 | rabo de peixe
# Processing Record 39 of Set 21 | miri
# Processing Record 40 of Set 21 | cap-aux-meules
# Processing Record 41 of Set 21 | yaan
# Processing Record 42 of Set 21 | haibowan
# City not found. Skipping...
# Processing Record 43 of Set 21 | yerbogachen
# Processing Record 44 of Set 21 | barra do garcas
# Processing Record 45 of Set 21 | zhanakorgan
# Processing Record 46 of Set 21 | saint-leu
# Processing Record 47 of Set 21 | gogrial
# Processing Record 48 of Set 21 | floriano
# Processing Record 49 of Set 21 | kailua
# Processing Record 50 of Set 21 | panaba
# Processing Record 1 of Set 22 | sovetskiy
# Processing Record 2 of Set 22 | upernavik
# Processing Record 3 of Set 22 | basco
# Processing Record 4 of Set 22 | acari
# Processing Record 5 of Set 22 | vestmannaeyjar
# Processing Record 6 of Set 22 | zubova polyana
# Processing Record 7 of Set 22 | provideniya
# Processing Record 8 of Set 22 | mbekenyera
# Processing Record 9 of Set 22 | kem
# Processing Record 10 of Set 22 | deputatskiy
# Processing Record 11 of Set 22 | sorland
# Processing Record 12 of Set 22 | novyy urgal
# Processing Record 13 of Set 22 | paradwip
# City not found. Skipping...
# Processing Record 14 of Set 22 | quesnel
# Processing Record 15 of Set 22 | fare
# Processing Record 16 of Set 22 | honiara
# Processing Record 17 of Set 22 | tromso
# Processing Record 18 of Set 22 | banda aceh
# Processing Record 19 of Set 22 | marsa matruh
# Processing Record 20 of Set 22 | caraballeda
# Processing Record 21 of Set 22 | oshogbo
# Processing Record 22 of Set 22 | phan rang
# City not found. Skipping...
# Processing Record 23 of Set 22 | manavalakurichi
# Processing Record 24 of Set 22 | werda
# Processing Record 25 of Set 22 | hammerfest
# Processing Record 26 of Set 22 | pangkalanbuun
# Processing Record 27 of Set 22 | nanortalik
# Processing Record 28 of Set 22 | la palma
# Processing Record 29 of Set 22 | gat
# Processing Record 30 of Set 22 | san quintin
# Processing Record 31 of Set 22 | wattegama
# Processing Record 32 of Set 22 | saint-pierre
# Processing Record 33 of Set 22 | batemans bay
# Processing Record 34 of Set 22 | berlevag
# Processing Record 35 of Set 22 | renqiu
# Processing Record 36 of Set 22 | nuevo progreso
# Processing Record 37 of Set 22 | baruun-urt
# Processing Record 38 of Set 22 | san patricio
# Processing Record 39 of Set 22 | bilma
# Processing Record 40 of Set 22 | xiaoyi
# Processing Record 41 of Set 22 | vardo
# Processing Record 42 of Set 22 | armidale
# Processing Record 43 of Set 22 | port moresby
# Processing Record 44 of Set 22 | lagunillas
# Processing Record 45 of Set 22 | ambon
# Processing Record 46 of Set 22 | daru
# Processing Record 47 of Set 22 | cayenne
# Processing Record 48 of Set 22 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 49 of Set 22 | port macquarie
# Processing Record 50 of Set 22 | bankra
# Processing Record 1 of Set 23 | westport
# Processing Record 2 of Set 23 | dvinskoy
# Processing Record 3 of Set 23 | tucupita
# Processing Record 4 of Set 23 | rio gallegos
# Processing Record 5 of Set 23 | prado
# Processing Record 6 of Set 23 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 23 | mount gambier
# Processing Record 8 of Set 23 | davila
# Processing Record 9 of Set 23 | evensk
# Processing Record 10 of Set 23 | maceio
# Processing Record 11 of Set 23 | sioux lookout
# Processing Record 12 of Set 23 | sungurlu
# Processing Record 13 of Set 23 | te anau
# Processing Record 14 of Set 23 | labuhan
# Processing Record 15 of Set 23 | alekseyevsk
# Processing Record 16 of Set 23 | novikovo
# Processing Record 17 of Set 23 | ambilobe
# Processing Record 18 of Set 23 | bimbo
# Processing Record 19 of Set 23 | ossora
# Processing Record 20 of Set 23 | ialibu
# Processing Record 21 of Set 23 | matara
# Processing Record 22 of Set 23 | adrar
# Processing Record 23 of Set 23 | beringovskiy
# Processing Record 24 of Set 23 | atar
# Processing Record 25 of Set 23 | christchurch
# Processing Record 26 of Set 23 | sieradz
# Processing Record 27 of Set 23 | hasaki
# Processing Record 28 of Set 23 | nkhata bay
# Processing Record 29 of Set 23 | katsuura
# Processing Record 30 of Set 23 | bolsheustikinskoye
# City not found. Skipping...
# Processing Record 31 of Set 23 | tilichiki
# Processing Record 32 of Set 23 | marfino
# Processing Record 33 of Set 23 | stornoway
# Processing Record 34 of Set 23 | ulaanbaatar
# Processing Record 35 of Set 23 | tual
# Processing Record 36 of Set 23 | batagay
# Processing Record 37 of Set 23 | dalvik
# Processing Record 38 of Set 23 | port blair
# Processing Record 39 of Set 23 | iquique
# Processing Record 40 of Set 23 | pudozh
# Processing Record 41 of Set 23 | mukhanovo
# City not found. Skipping...
# Processing Record 42 of Set 23 | grindavik
# Processing Record 43 of Set 23 | mae ramat
# Processing Record 44 of Set 23 | milkovo
# Processing Record 45 of Set 23 | esperance
# Processing Record 46 of Set 23 | le port
# Processing Record 47 of Set 23 | ponta delgada
# Processing Record 48 of Set 23 | otane
# Processing Record 49 of Set 23 | shirokiy
# Processing Record 50 of Set 23 | jinchengjiang
# City not found. Skipping...
# Processing Record 1 of Set 24 | decatur
# Processing Record 2 of Set 24 | aflu
# City not found. Skipping...
# Processing Record 3 of Set 24 | okhotsk
# Processing Record 4 of Set 24 | carbondale
# Processing Record 5 of Set 24 | balykshi
# Processing Record 6 of Set 24 | manubul
# Processing Record 7 of Set 24 | pahrump
# Processing Record 8 of Set 24 | coahuayana
# Processing Record 9 of Set 24 | bur gabo
# City not found. Skipping...
# Processing Record 10 of Set 24 | naze
# Processing Record 11 of Set 24 | bogorodskoye
# Processing Record 12 of Set 24 | port lincoln
# Processing Record 13 of Set 24 | partizanske
# Processing Record 14 of Set 24 | honolulu
# Processing Record 15 of Set 24 | sirjan
# Processing Record 16 of Set 24 | mubi
# Processing Record 17 of Set 24 | novobirilyussy
# Processing Record 18 of Set 24 | oltu
# Processing Record 19 of Set 24 | serafimovich
# Processing Record 20 of Set 24 | taburi
# City not found. Skipping...
# Processing Record 21 of Set 24 | arman
# Processing Record 22 of Set 24 | mocajuba
# Processing Record 23 of Set 24 | bukama
# Processing Record 24 of Set 24 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 24 | kalabo
# Processing Record 26 of Set 24 | porbandar
# Processing Record 27 of Set 24 | yar-sale
# Processing Record 28 of Set 24 | acarau
# Processing Record 29 of Set 24 | pondicherry
# Processing Record 30 of Set 24 | grand gaube
# Processing Record 31 of Set 24 | beloha
# Processing Record 32 of Set 24 | hualmay
# Processing Record 33 of Set 24 | norman wells
# Processing Record 34 of Set 24 | santa cruz de tenerife
# Processing Record 35 of Set 24 | kirkland lake
# Processing Record 36 of Set 24 | camacari
# Processing Record 37 of Set 24 | orlik
# Processing Record 38 of Set 24 | puerto boyaca
# Processing Record 39 of Set 24 | kasama
# Processing Record 40 of Set 24 | gornyak
# Processing Record 41 of Set 24 | denia
# Processing Record 42 of Set 24 | partenit
# Processing Record 43 of Set 24 | ardmore
# Processing Record 44 of Set 24 | yomitan
# City not found. Skipping...
# Processing Record 45 of Set 24 | kondoa
# Processing Record 46 of Set 24 | alamosa
# Processing Record 47 of Set 24 | panshi
# Processing Record 48 of Set 24 | matagami
# Processing Record 49 of Set 24 | jiddah
# City not found. Skipping...
# Processing Record 50 of Set 24 | nichlaul
# Processing Record 1 of Set 25 | soyo
# Processing Record 2 of Set 25 | bintulu
# Processing Record 3 of Set 25 | ati
# Processing Record 4 of Set 25 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 25 | marondera
# Processing Record 6 of Set 25 | chernyshevskiy
# Processing Record 7 of Set 25 | louisbourg
# City not found. Skipping...
# Processing Record 8 of Set 25 | saldanha
# Processing Record 9 of Set 25 | sidi ali
# Processing Record 10 of Set 25 | sale
# Processing Record 11 of Set 25 | tongling
# Processing Record 12 of Set 25 | karamea
# City not found. Skipping...
# Processing Record 13 of Set 25 | broken hill
# Processing Record 14 of Set 25 | mitsamiouli
# Processing Record 15 of Set 25 | phan thiet
# Processing Record 16 of Set 25 | tura
# Processing Record 17 of Set 25 | hofn
# Processing Record 18 of Set 25 | shetpe
# Processing Record 19 of Set 25 | miandrivazo
# Processing Record 20 of Set 25 | tazovskiy
# Processing Record 21 of Set 25 | moses lake
# Processing Record 22 of Set 25 | walvis bay
# Processing Record 23 of Set 25 | kuche
# City not found. Skipping...
# Processing Record 24 of Set 25 | santa maria
# Processing Record 25 of Set 25 | gasa
# Processing Record 26 of Set 25 | ekhabi
# Processing Record 27 of Set 25 | belmonte
# Processing Record 28 of Set 25 | kamaishi
# Processing Record 29 of Set 25 | riviere-au-renard
# Processing Record 30 of Set 25 | lompoc
# Processing Record 31 of Set 25 | ostrovnoy
# Processing Record 32 of Set 25 | umm kaddadah
# Processing Record 33 of Set 25 | lensk
# Processing Record 34 of Set 25 | perg
# Processing Record 35 of Set 25 | ust-ishim
# Processing Record 36 of Set 25 | bedele
# Processing Record 37 of Set 25 | touros
# Processing Record 38 of Set 25 | opuwo
# Processing Record 39 of Set 25 | barawe
# City not found. Skipping...
# Processing Record 40 of Set 25 | bisauli
# Processing Record 41 of Set 25 | jasper
# Processing Record 42 of Set 25 | gzhatsk
# City not found. Skipping...
# Processing Record 43 of Set 25 | the valley
# Processing Record 44 of Set 25 | lusaka
# Processing Record 45 of Set 25 | hanna
# Processing Record 46 of Set 25 | veraval
# Processing Record 47 of Set 25 | cabadiangan
# Processing Record 48 of Set 25 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 25 | luwuk
# Processing Record 50 of Set 25 | puerto escondido
# Processing Record 1 of Set 26 | peraiyur
# Processing Record 2 of Set 26 | yantal
# Processing Record 3 of Set 26 | surt
# Processing Record 4 of Set 26 | jieshi
# Processing Record 5 of Set 26 | fairbanks
# Processing Record 6 of Set 26 | los llanos de aridane
# Processing Record 7 of Set 26 | cauquenes
# Processing Record 8 of Set 26 | martinopolis
# Processing Record 9 of Set 26 | martapura
# Processing Record 10 of Set 26 | vylgort
# City not found. Skipping...
# Processing Record 11 of Set 26 | xai-xai
# Processing Record 12 of Set 26 | moa
# Processing Record 13 of Set 26 | tucuma
# Processing Record 14 of Set 26 | angoche
# Processing Record 15 of Set 26 | zonguldak
# Processing Record 16 of Set 26 | laguna
# Processing Record 17 of Set 26 | erenhot
# Processing Record 18 of Set 26 | omboue
# Processing Record 19 of Set 26 | marsh harbour
# Processing Record 20 of Set 26 | hengshui
# Processing Record 21 of Set 26 | chiang khong
# Processing Record 22 of Set 26 | willowmore
# Processing Record 23 of Set 26 | turbat
# Processing Record 24 of Set 26 | chau doc
# Processing Record 25 of Set 26 | dwarka
# Processing Record 26 of Set 26 | pousat
# City not found. Skipping...
# Processing Record 27 of Set 26 | rastede
# Processing Record 28 of Set 26 | macas
# Processing Record 29 of Set 26 | tonj
# Processing Record 30 of Set 26 | tiarei
# Processing Record 31 of Set 26 | luganville
# Processing Record 32 of Set 26 | lichinga
# Processing Record 33 of Set 26 | nisporeni
# Processing Record 34 of Set 26 | harrison
# Processing Record 35 of Set 26 | ginda
# Processing Record 36 of Set 26 | snezhnogorsk
# Processing Record 37 of Set 26 | srednekolymsk
# Processing Record 38 of Set 26 | faya
# Processing Record 39 of Set 26 | roald
# Processing Record 40 of Set 26 | sedelnikovo
# City not found. Skipping...
# Processing Record 41 of Set 26 | muscle shoals
# Processing Record 42 of Set 26 | sistranda
# Processing Record 43 of Set 26 | lata
# Processing Record 44 of Set 26 | cordoba
# Processing Record 45 of Set 26 | cuiluan
# Processing Record 46 of Set 26 | buraydah
# Processing Record 47 of Set 26 | champasak
# Processing Record 48 of Set 26 | sanchor
# Processing Record 49 of Set 26 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 50 of Set 26 | boda
# Processing Record 1 of Set 27 | baft
# Processing Record 2 of Set 27 | navirai
# Processing Record 3 of Set 27 | massakory
# Processing Record 4 of Set 27 | tenosique
# Processing Record 5 of Set 27 | mrirt
# City not found. Skipping...
# Processing Record 6 of Set 27 | meulaboh
# Processing Record 7 of Set 27 | heishan
# Processing Record 8 of Set 27 | mayo
# Processing Record 9 of Set 27 | apt
# Processing Record 10 of Set 27 | borba
# Processing Record 11 of Set 27 | concordia
# Processing Record 12 of Set 27 | broome
# Processing Record 13 of Set 27 | rio branco
# Processing Record 14 of Set 27 | nogent-le-rotrou
# Processing Record 15 of Set 27 | inhambane
# Processing Record 16 of Set 27 | segou
# Processing Record 17 of Set 27 | saint-denis
# Processing Record 18 of Set 27 | kariba
# Processing Record 19 of Set 27 | whitehorse
# Processing Record 20 of Set 27 | machico
# Processing Record 21 of Set 27 | geraldton
# Processing Record 22 of Set 27 | petropavlovsk-kamchatskiy
# Processing Record 23 of Set 27 | ormara
# Processing Record 24 of Set 27 | khandbari
# Processing Record 25 of Set 27 | tommot
# Processing Record 26 of Set 27 | do rud
# City not found. Skipping...
# Processing Record 27 of Set 27 | zdunska wola
# Processing Record 28 of Set 27 | kodinsk
# Processing Record 29 of Set 27 | aklavik
# Processing Record 30 of Set 27 | kargasok
# Processing Record 31 of Set 27 | hayward
# Processing Record 32 of Set 27 | oktyabrskoye
# Processing Record 33 of Set 27 | jamsa
# Processing Record 34 of Set 27 | madera
# Processing Record 35 of Set 27 | manta
# Processing Record 36 of Set 27 | koshki
# Processing Record 37 of Set 27 | aksaray
# Processing Record 38 of Set 27 | carballo
# Processing Record 39 of Set 27 | la ronge
# Processing Record 40 of Set 27 | mago
# Processing Record 41 of Set 27 | labuan
# Processing Record 42 of Set 27 | kimbe
# Processing Record 43 of Set 27 | kuching
# Processing Record 44 of Set 27 | binzhou
# Processing Record 45 of Set 27 | riyadh
# Processing Record 46 of Set 27 | praia
# Processing Record 47 of Set 27 | dzhusaly
# City not found. Skipping...
# Processing Record 48 of Set 27 | bara
# Processing Record 49 of Set 27 | mandalgovi
# Processing Record 50 of Set 27 | svetlogorsk
# Processing Record 1 of Set 28 | batticaloa
# Processing Record 2 of Set 28 | waingapu
# Processing Record 3 of Set 28 | odweyne
# Processing Record 4 of Set 28 | qaqortoq
# Processing Record 5 of Set 28 | umm lajj
# Processing Record 6 of Set 28 | mahon
# Processing Record 7 of Set 28 | tubruq
# City not found. Skipping...
# Processing Record 8 of Set 28 | esmeraldas
# Processing Record 9 of Set 28 | requena
# Processing Record 10 of Set 28 | rundu
# Processing Record 11 of Set 28 | vanimo
# Processing Record 12 of Set 28 | pori
# Processing Record 13 of Set 28 | casselman
# Processing Record 14 of Set 28 | patacamaya
# Processing Record 15 of Set 28 | santa cruz
# Processing Record 16 of Set 28 | khatanga
# Processing Record 17 of Set 28 | marzuq
# Processing Record 18 of Set 28 | yarada
# Processing Record 19 of Set 28 | meyungs
# City not found. Skipping...
# Processing Record 20 of Set 28 | ipora
# Processing Record 21 of Set 28 | wanganui
# Processing Record 22 of Set 28 | alpena
# Processing Record 23 of Set 28 | tessalit
# Processing Record 24 of Set 28 | sambava
# Processing Record 25 of Set 28 | saint-francois
# Processing Record 26 of Set 28 | raudeberg
# Processing Record 27 of Set 28 | hearst
# Processing Record 28 of Set 28 | sao domingos
# Processing Record 29 of Set 28 | banamba
# Processing Record 30 of Set 28 | kokoda
# Processing Record 31 of Set 28 | puerto montt
# Processing Record 32 of Set 28 | zhigansk
# Processing Record 33 of Set 28 | jizan
# Processing Record 34 of Set 28 | burns lake
# Processing Record 35 of Set 28 | strezhevoy
# Processing Record 36 of Set 28 | kosino
# Processing Record 37 of Set 28 | sur
# Processing Record 38 of Set 28 | kaseda
# Processing Record 39 of Set 28 | the pas
# Processing Record 40 of Set 28 | lucapa
# Processing Record 41 of Set 28 | mattru
# Processing Record 42 of Set 28 | palana
# Processing Record 43 of Set 28 | hamilton
# Processing Record 44 of Set 28 | durazno
# Processing Record 45 of Set 28 | korla
# Processing Record 46 of Set 28 | florida
# Processing Record 47 of Set 28 | ridgecrest
# Processing Record 48 of Set 28 | axim
# Processing Record 49 of Set 28 | ahipara
# Processing Record 50 of Set 28 | zeya
# Processing Record 1 of Set 29 | karla
# Processing Record 2 of Set 29 | heiligenhafen
# Processing Record 3 of Set 29 | libenge
# Processing Record 4 of Set 29 | maamba
# Processing Record 5 of Set 29 | herat
# Processing Record 6 of Set 29 | abu samrah
# Processing Record 7 of Set 29 | asau
# Processing Record 8 of Set 29 | antofagasta
# Processing Record 9 of Set 29 | ongandjera
# Processing Record 10 of Set 29 | byron bay
# Processing Record 11 of Set 29 | zyryanka
# Processing Record 12 of Set 29 | bagdarin
# Processing Record 13 of Set 29 | ola
# Processing Record 14 of Set 29 | wuwei
# Processing Record 15 of Set 29 | lovozero
# Processing Record 16 of Set 29 | fisciano
# Processing Record 17 of Set 29 | karaidel
# Processing Record 18 of Set 29 | salalah
# Processing Record 19 of Set 29 | salto
# Processing Record 20 of Set 29 | babstovo
# Processing Record 21 of Set 29 | koungou
# Processing Record 22 of Set 29 | agadir
# Processing Record 23 of Set 29 | fort morgan
# Processing Record 24 of Set 29 | smithers
# Processing Record 25 of Set 29 | pangai
# Processing Record 26 of Set 29 | najran
# Processing Record 27 of Set 29 | beruwala
# Processing Record 28 of Set 29 | paracuru
# Processing Record 29 of Set 29 | sept-iles
# Processing Record 30 of Set 29 | petukhovo
# Processing Record 31 of Set 29 | yingcheng
# Processing Record 32 of Set 29 | clonakilty
# Processing Record 33 of Set 29 | kapoeta
# Processing Record 34 of Set 29 | sinnamary
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Avarua -21.2078 -159.7750     86.00        79          75
# 1      Esperance -33.8667  121.9000     51.80        93          67
# 2     Nikolskoye  59.7035   30.7861     37.99        81          90
# 3      Dong Xoai  11.5333  106.9167     72.86        85          92
# 4         Touros  -5.1989  -35.4608     78.80        89          75
# ...          ...      ...       ...       ...       ...         ...
# 5130   Petukhovo  55.0692   67.9019     24.64        95         100
# 5131   Yingcheng  30.9500  113.5500     59.00        63           0
# 5132  Clonakilty  51.6231   -8.8706     43.00        93          40
# 5133     Kapoeta   4.7717   33.5903     82.71        31          25
# 5134   Sinnamary   5.3833  -52.9500     76.73        86         100
#
#       Wind Speed Country Current Description
# 0          18.41      CK                 NaN
# 1           8.05      AU                 NaN
# 2           8.95      RU                 NaN
# 3           2.66      VN                 NaN
# 4           9.22      BR                 NaN
# ...          ...     ...                 ...
# 5130       12.35      RU          light snow
# 5131        8.95      CN           clear sky
# 5132        8.05      IE    scattered clouds
# 5133       13.73      SS    scattered clouds
# 5134        9.55      GF     overcast clouds
#
# [5135 rows x 9 columns]

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Avarua      CK -21.2078 -159.7750     86.00        79          75
# 1      Esperance      AU -33.8667  121.9000     51.80        93          67
# 2     Nikolskoye      RU  59.7035   30.7861     37.99        81          90
# 3      Dong Xoai      VN  11.5333  106.9167     72.86        85          92
# 4         Touros      BR  -5.1989  -35.4608     78.80        89          75
# ...          ...     ...      ...       ...       ...       ...         ...
# 5130   Petukhovo      RU  55.0692   67.9019     24.64        95         100
# 5131   Yingcheng      CN  30.9500  113.5500     59.00        63           0
# 5132  Clonakilty      IE  51.6231   -8.8706     43.00        93          40
# 5133     Kapoeta      SS   4.7717   33.5903     82.71        31          25
# 5134   Sinnamary      GF   5.3833  -52.9500     76.73        86         100
#
#       Wind Speed Current Description
# 0          18.41                 NaN
# 1           8.05                 NaN
# 2           8.95                 NaN
# 3           2.66                 NaN
# 4           9.22                 NaN
# ...          ...                 ...
# 5130       12.35          light snow
# 5131        8.95           clear sky
# 5132        8.05    scattered clouds
# 5133       13.73    scattered clouds
# 5134        9.55     overcast clouds
#
# [5135 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weatherpy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
